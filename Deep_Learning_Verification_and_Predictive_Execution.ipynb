# %% [markdown]
# <a href="https://colab.research.google.com/github/clzndyal1/git_test/blob/master/Deep_Learning_Verification_and_Predictive_Execution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# !git clone https://github.com/taehojo/data.git

df = pd.read_csv('./data/sonar3.csv')

df.head()
# Out:
# fatal: destination path 'data' already exists and is not an empty directory.
#      0.02  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109  \
# 0  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 1  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 2  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 3  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# 4  0.0286  0.0453  0.0277  0.0174  0.0384  0.0990  0.1201  0.1833  0.2105
#
#    0.2111  ...  0.0027  0.0065  0.0159  0.0072  0.0167   0.018  0.0084  \
# 0  0.2872  ...  0.0084  0.0089  0.0048  0.0094  0.0191  0.0140  0.0049
# 1  0.6194  ...  0.0232  0.0166  0.0095  0.0180  0.0244  0.0316  0.0164
# 2  0.1264  ...  0.0121  0.0036  0.0150  0.0085  0.0073  0.0050  0.0044
# 3  0.4459  ...  0.0031  0.0054  0.0105  0.0110  0.0015  0.0072  0.0048
# 4  0.3039  ...  0.0045  0.0014  0.0038  0.0013  0.0089  0.0057  0.0027
#
# ...

# %%
X = df.iloc[:,0:-1]
y = df.iloc[:,-1]

# %%
model = Sequential()
model.add(Dense(24, input_dim = 60, activation='relu'))   #input_layer_1
model.add(Dense(10, activation='relu'))  #layer_2
model.add(Dense(1, activation='sigmoid'))  #layer_3
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_3 (Dense)             (None, 24)                1464
#
#  dense_4 (Dense)             (None, 10)                250
#
#  dense_5 (Dense)             (None, 1)                 11
#
# ...
# Total params: 1,725
# Trainable params: 1,725
# Non-trainable params: 0
# _________________________________________________________________

# %%
#모델 컴파일
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

#모델을 실행
history = model.fit(X, y, epochs=200, batch_size=10)
# Out:
# Epoch 1/200
# 21/21 [==============================] - 1s 2ms/step - loss: 0.7485 - accuracy: 0.4541
# Epoch 2/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.6911 - accuracy: 0.5314
# Epoch 3/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.6705 - accuracy: 0.6425
# Epoch 4/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.6553 - accuracy: 0.6812
# Epoch 5/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.6418 - accuracy: 0.6812
# Epoch 6/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.6267 - accuracy: 0.6908
# Epoch 7/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.6112 - accuracy: 0.7295
# Epoch 8/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.5982 - accuracy: 0.7198
# Epoch 9/200
# 21/21 [==============================] - 0s 2ms/step - loss: 0.5796 - accuracy: 0.7391
# Epoch 10/200
# ...
