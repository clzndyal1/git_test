# %% [markdown]
# <a href="https://colab.research.google.com/github/clzndyal1/git_test/blob/master/Deep_Learning_tensorflow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#텐서플로우를 활용한 선형 회귀분석
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.array([2,4,6,8])
y = np.array([81, 93, 91, 97])

model = Sequential()

#출력 값, 입력변수, 분석 방법에 맞게끔 모델을 설정
model.add(Dense(1, input_dim=1, activation='linear'))

#오차 수정을 위해 경사하강법(sgd)을 오차의 정도를 판단하기 위해
#평균 제곱 오차(mse)를 사용합니다.
model.compile(optimizer='sgd', loss='mse')

#오차를 최소화하는 과정을 2000번 반복합니다.

model.fit(x, y, epochs=2000)

plt.scatter(x, y)
plt.plot(x, model.predict(x), 'r')  #예측결과를 그래프로 나타냅니다.
plt.show()

#임의의 시간을 집어넣어 점수를 예측하는 모델을 테스트해 보겠습니다.
hour = 7
prediction = model.predict([hour])
print('%.f시간을 공부할 경우의 예상점수는 %.02f점입니다.' %(hour, prediction))
# Out:
# Epoch 1/2000
# 1/1 [==============================] - 0s 274ms/step - loss: 7388.6260
# Epoch 2/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 1920.7756
# Epoch 3/2000
# 1/1 [==============================] - 0s 8ms/step - loss: 1112.3207
# Epoch 4/2000
# 1/1 [==============================] - 0s 8ms/step - loss: 988.2490
# Epoch 5/2000
# 1/1 [==============================] - 0s 8ms/step - loss: 964.7308
# Epoch 6/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 956.0155
# Epoch 7/2000
# 1/1 [==============================] - 0s 10ms/step - loss: 949.5087
# Epoch 8/2000
# 1/1 [==============================] - 0s 9ms/step - loss: 943.3599
# Epoch 9/2000
# 1/1 [==============================] - 0s 8ms/step - loss: 937.2974
# Epoch 10/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 931.2809
# Epoch 11/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 925.3044
# Epoch 12/2000
# ...

# %%
#다중 선형 회귀 분석 -> 텐서플로우로

x = np.array([[2,0], [4,4], [6,2], [8,3]])
y = np.array([81, 93, 91, 97])

model = Sequential()

#출력 값, 입력변수, 분석 방법에 맞게끔 모델을 설정
model.add(Dense(10, input_dim=2, activation='relu')) #layer추가
model.add(Dense(1, activation='linear'))  #layer추가

#오차 수정을 위해 경사하강법(sgd)을 오차의 정도를 판단하기 위해
#평균 제곱 오차(mse)를 사용합니다.
model.compile(optimizer='sgd', loss='mse')

#오차를 최소화하는 과정을 2000번 반복합니다.
model.fit(x, y, epochs=2000)
# Out:
# Epoch 1/2000
# 1/1 [==============================] - 0s 399ms/step - loss: 8055.7402
# Epoch 2/2000
# 1/1 [==============================] - 0s 9ms/step - loss: 22693.9297
# Epoch 3/2000
# 1/1 [==============================] - 0s 10ms/step - loss: 8349.2373
# Epoch 4/2000
# 1/1 [==============================] - 0s 8ms/step - loss: 8019.9834
# Epoch 5/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 7703.7666
# Epoch 6/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 7400.0742
# Epoch 7/2000
# 1/1 [==============================] - 0s 10ms/step - loss: 7108.4067
# Epoch 8/2000
# 1/1 [==============================] - 0s 9ms/step - loss: 6828.2900
# Epoch 9/2000
# 1/1 [==============================] - 0s 8ms/step - loss: 6559.2656
# Epoch 10/2000
# 1/1 [==============================] - 0s 8ms/step - loss: 6300.8955
# Epoch 11/2000
# 1/1 [==============================] - 0s 8ms/step - loss: 6052.7559
# Epoch 12/2000
# ...

# %%
#7시간, 과외를 4회 했을때 성적을 예측

hour = 7
private_class = 4
prediction = model.predict([[hour, private_class]])
print('%.f시간을 공부하고 %.f시간의 과외를 받을경우, 예상점수는 %.02f점 입니다.' %(hour, private_class, prediction))
# Out:
# 1/1 [==============================] - 0s 72ms/step
# 7시간을 공부하고 4시간의 과외를 받을경우, 예상점수는 90.50점 입니다.

# %%
#텐서플로에서 실행하는 로지스틱 회귀 모델

#로지스틱 회귀분석
x = np.array([2, 4, 6, 8, 10, 12, 14])
y = np.array([0,0,0,1,1,1,1])

model = Sequential()

model.add(Dense(1, input_dim=1,activation = 'sigmoid'))  #이진분류이므로 시그모이드 함수 사용
model.compile(optimizer = 'sgd', loss = 'binary_crossentropy')
model.fit(x, y, epochs=5000)

#그래프 확인
plt.scatter(x, y) 
plt.plot(x, model.predict(x), 'r')  #예측선으로 표기
plt.show()

#공부시간이 7시간인 경우 합격여부 확인
hour = 7
prediction = model.predict([hour])
print('%.f시간을 공부할 경우, 합격 예상 확률은 %.01f%%입니다.' %(hour, prediction*100))
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# Epoch 1222/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.3600
# Epoch 1223/5000
# 1/1 [==============================] - 0s 10ms/step - loss: 0.3599
# Epoch 1224/5000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.3598
# Epoch 1225/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.3597
# Epoch 1226/5000
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3596
# Epoch 1227/5000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.3595
# Epoch 1228/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.3594
# Epoch 1229/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.3593
# Epoch 1230/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.3592
# Epoch 1231/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.3590
# Epoch 1232/5000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.3589
# ...
